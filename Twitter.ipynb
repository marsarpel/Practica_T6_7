# %% [markdown]
# # Twitter y MongoDB

# %% [markdown]
# De las múltiples librerías que nos permiten usar la API de Twitter, usaremos [Python Twitter Tools](https://github.com/sixohsix/twitter). Con esta librería podremos descargar tweets e información de sus usuarios, así que el **ejercicio** será modelar estas dos entidades y almacenar instancias de ellas.
#
# La idea de este ejercicio está basada en uno anterior que realizó [Gabriel Muñoz](https://twitter.com/Gabi_mu_ri).

# %% [markdown]
# ## Requisitos

# %% [markdown]
# * Python:
#   * `jupyter`
#   * [`twitter`](https://github.com/sixohsix/twitter)
#   * `pymongo`
#   * `mongoengine`
# * MongoDB

# %% [markdown]
# ## El modelo

# %% [markdown]
# Más o menos todos tenemos en la cabeza como funciona Twitter:
# * Un usuario puede publicar cero o muchos tweets.
# * Un tweet tienes varias propiedades, siendo una de ellas el tweet en si, donde podemos encontrar:
#   * Texto.
#   * Menciones a otros usuarios: [`@josemazo`](https://twitter.com/josemazo).
#   * Enlaces: [`https://www.mongodb.org/`](https://www.mongodb.org/).
#   * Hashtags: `#MongoDB`.

# %% [markdown]
# ## Autorización

# %% [markdown]
# Para usar la API pública de Twitter necesitamos ciertos parámetros, así que vamos a ver como obtenerlos.
# 1. Debemos tener una cuenta en Twitter y estar logueados.
# 2. Visitamos [https://apps.twitter.com/](https://apps.twitter.com/) y pulsamos sobre **`Create New App`**.
# ![Pasos 1 y 2](https://i.imgur.com/85p8ROC.png)
# 3. Rellenamos los campos obligatorios:
#   * **`Name`**: debe ser único.
#   * **`Description`**: debe tener más de 10 carácteres.
#   * **`Website`**: debe ser una URL válida.
#   * **`Yes, I agree`**: debemos marcar ese checkbox.
#   * Finalmente puslamos sobre **`Create your Twitter application`**.
# ![Paso 3](https://i.imgur.com/Yi3vATT.png)
# 4. Pulsamos en el enlace **`Keys and Access Tokens`**.
# ![Paso 4](https://i.imgur.com/BVbSK4M.png)
# 5. En `Application Settings` tenemos dos de los parámetros que necesitamos:
#   * **`Consumer Key`**
#   * **`Consumer Secret`**
# ![Paso 5](https://i.imgur.com/R0UQFTq.png)
# 6. Al final de la misma página hay un botón que dice **`Create my access token`**, pulsamos sobre él.
# ![Paso 6](https://i.imgur.com/x6HO5Wy.png)
# 7. De nuevo al final de esa misma página, bajo `Your Access Token` tenemos los otros dos parámetros restantes:
#   * **`Access Token`**
#   * **`Access Token Secret`**
# ![Paso 7](https://i.imgur.com/oNvj1z5.png)

# %% [markdown]
# ## ¡A programar!

# %%
# Importing packages
from bson.objectid import ObjectId
import datetime
from mongoengine import *
import twitter

# %%
# Twitter configuration, we need to use the parameters that we got before
ACCESS_TOKEN = '2317308488-meQkAvVx6PlIBTK95doeG3dWFAFTspP7p1mWBSk'
ACCESS_TOKEN_SECRET = 'ALFdtf8wSI5AABbZV57zyA88tOhcMKEE6Y6cqZp4dzQ7Y'
CONSUMER_KEY = 'epdtTPBqzcR8yHl6KjGO9wirp'
CONSUMER_SECRET ='R3ebevBSe3XaAFfxzxhU1JAalAXd6md9jvBlaIAcyy2rPyY1B3'

auth = twitter.oauth.OAuth(ACCESS_TOKEN, ACCESS_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(auth=auth)

# %%
# MongoDB configuration
connect('twitter', host='localhost', port=27017)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True, read_preference=Primary())

# %% [markdown]
# Vamos a obtener tweets, para ellos usaremos la API y veremos que nos devuelve.

# %%
# Obtaining tweets
search_word = 'Big data'  # We can search by a word, a text or a hashtag
count = 100

search_results = twitter_api.search.tweets(q=search_word, count=count, lang='es')
search_results
# Out:
# {'search_metadata': {'completed_in': 0.128,
#   'count': 100,
#   'max_id': 822373174771937280,
#   'max_id_str': '822373174771937280',
#   'next_results': '?max_id=822340870854897663&q=Big%20data&lang=es&count=100&include_entities=1',
#   'query': 'Big+data',
#   'refresh_url': '?since_id=822373174771937280&q=Big%20data&lang=es&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:20:18 +0000 2017',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'BigData'},
#      {'indices': [82, 92], 'text': 'SmartCity'}],
#     'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#       'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#       'id': 822373172460867584,
#       'id_str': '822373172460867584',
#       'indices': [93, 116],
#       'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#       'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#        'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#        'small': {'h': 607, 'resize': 'fit', 'w': 500},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/S2go0oLgPW'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/2j1mMWW',
#       'expanded_url': 'http://bit.ly/2j1mMWW',
#       'indices': [58, 81],
#       'url': 'https://t.co/iQJYS78ZDD'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#       'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#       'id': 822373172460867584,
#       'id_str': '822373172460867584',
#       'indices': [93, 116],
#       'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#       'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#        'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#        'small': {'h': 607, 'resize': 'fit', 'w': 500},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/S2go0oLgPW'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822373174771937280,
#    'id_str': '822373174771937280',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': '#BigData en las ciudades y ejemplos perfectos de utilidad https://t.co/iQJYS78ZDD #SmartCity https://t.co/S2go0oLgPW',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 29 00:40:22 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#Comunicación #Marketing #Tech #BigData #SmartCity #DirCom #Cloud #Digital',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 896,
#     'follow_request_sent': False,
#     'followers_count': 1892,
#     'following': False,
#     'friends_count': 1586,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 423842030,
#     'id_str': '423842030',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 99,
#     'location': '',
#     'name': 'Nacho Albert López',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/423842030/1455270387',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#     'profile_link_color': '0C087F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Nachoctv',
#     'statuses_count': 706,
#     'time_zone': 'Belgrade',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:19:26 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'ticbeat.com/tecnologias/al…',
#       'expanded_url': 'http://www.ticbeat.com/tecnologias/alibaba-servicios-big-data-middleware/',
#       'indices': [78, 101],
#       'url': 'https://t.co/F274EhLSAr'}],
#     'user_mentions': [{'id': 82061776,
#       'id_str': '82061776',
#       'indices': [106, 114],
#       'name': 'TICbeat',
#       'screen_name': 'ticbeat'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822372958211452928,
#    'id_str': '822372958211452928',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'El gigante chino Alibaba lanza alianza para luchar contra las falsificaciones https://t.co/F274EhLSAr vía @ticbeat',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Aug 09 21:39:20 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 22961,
#     'follow_request_sent': False,
#     'followers_count': 3769,
#     'following': False,
#     'friends_count': 3845,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 351895201,
#     'id_str': '351895201',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 49,
#     'location': 'Canary Islands (Spain)',
#     'name': 'José Pablo',
#     'notifications': False,
#     'profile_background_color': 'FFFFFF',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/450336226394906624/R7XfDFng.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/450336226394906624/R7XfDFng.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/351895201/1468796572',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/809139692272762881/7A5pGOcM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/809139692272762881/7A5pGOcM_normal.jpg',
#     'profile_link_color': '22A7BF',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'JPabloGlezRob',
#     'statuses_count': 34660,
#     'time_zone': 'London',
#     'translator_type': 'regular',
#     'url': None,
#     'utc_offset': 0,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:18:03 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'theguardian.com/politics/2017/…',
#       'expanded_url': 'https://www.theguardian.com/politics/2017/jan/19/crisis-of-statistics-big-data-democracy',
#       'indices': [72, 95],
#       'url': 'https://t.co/wL1Sdr2y0r'}],
#     'user_mentions': [{'id': 1477811,
#       'id_str': '1477811',
#       'indices': [3, 12],
#       'name': 'Antonio Delgado',
#       'screen_name': 'adelgado'},
#      {'id': 10361342,
#       'id_str': '10361342',
#       'indices': [100, 109],
#       'name': 'Kiko Llaneras',
#       'screen_name': 'kikollan'},
#      {'id': 69350769,
#       'id_str': '69350769',
#       'indices': [110, 121],
#       'name': 'Josu Mezo',
#       'screen_name': 'malaprensa'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822372606628151296,
#    'id_str': '822372606628151296',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Jan 20 08:27:09 +0000 2017',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'theguardian.com/politics/2017/…',
#        'expanded_url': 'https://www.theguardian.com/politics/2017/jan/19/crisis-of-statistics-big-data-democracy',
#        'indices': [58, 81],
#        'url': 'https://t.co/wL1Sdr2y0r'}],
#      'user_mentions': [{'id': 10361342,
#        'id_str': '10361342',
#        'indices': [86, 95],
#        'name': 'Kiko Llaneras',
#        'screen_name': 'kikollan'},
#       {'id': 69350769,
#        'id_str': '69350769',
#        'indices': [96, 107],
#        'name': 'Josu Mezo',
#        'screen_name': 'malaprensa'}]},
#     'favorite_count': 8,
#     'favorited': False,
#     'geo': None,
#     'id': 822359801258790912,
#     'id_str': '822359801258790912',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 3,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Cómo la estadística pierde su poder y el miedo al bigdata https://t.co/wL1Sdr2y0r  cc @kikollan @malaprensa',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Mar 19 06:57:30 +0000 2007',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Periodista. Datos y visualización. Cofundador @datadista. Innovación editorial @Weblogssl. Profesor #ddj.  Organizo @redadaes PGP https://t.co/k9ThLpdBOx',
#      'entities': {'description': {'urls': [{'display_url': 'j.mp/adelgadokey',
#          'expanded_url': 'http://j.mp/adelgadokey',
#          'indices': [130, 153],
#          'url': 'https://t.co/k9ThLpdBOx'}]},
#       'url': {'urls': [{'display_url': 'antonio-delgado.com',
#          'expanded_url': 'http://www.antonio-delgado.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/IsrzN0nNUR'}]}},
#      'favourites_count': 13321,
#      'follow_request_sent': False,
#      'followers_count': 34453,
#      'following': False,
#      'friends_count': 2309,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 1477811,
#      'id_str': '1477811',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 2139,
#      'location': 'Madrid - Jerez - Valencia',
#      'name': 'Antonio Delgado',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1477811/1347995966',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1783118571/adelgado2011_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1783118571/adelgado2011_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'adelgado',
#      'statuses_count': 48189,
#      'time_zone': 'Madrid',
#      'translator_type': 'regular',
#      'url': 'https://t.co/IsrzN0nNUR',
#      'utc_offset': 3600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @adelgado: Cómo la estadística pierde su poder y el miedo al bigdata https://t.co/wL1Sdr2y0r  cc @kikollan @malaprensa',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu May 27 14:24:06 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Obstinada en investigar la comunicación digital (UV-UAB). Con mil proyectos en la cabeza y sin dejar de soñar. | 0x2B8F3C65',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 602,
#     'follow_request_sent': False,
#     'followers_count': 267,
#     'following': False,
#     'friends_count': 415,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 148753280,
#     'id_str': '148753280',
#     'is_translation_enabled': True,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 18,
#     'location': 'Luna de Valencia',
#     'name': 'Lorena Cano-Orón',
#     'notifications': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/339385277/Mariposas_Dal_.JPG',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/339385277/Mariposas_Dal_.JPG',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/148753280/1479375550',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/806761564611092480/ZmmUr-Lc_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806761564611092480/ZmmUr-Lc_normal.jpg',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': '8EC1E8',
#     'profile_sidebar_fill_color': 'CDEFF7',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Loreneando',
#     'statuses_count': 2419,
#     'time_zone': 'Greenland',
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:15:34 +0000 2017',
#    'entities': {'hashtags': [{'indices': [3, 11], 'text': 'BigData'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#       'expanded_url': 'https://twitter.com/i/web/status/822371983203545088',
#       'indices': [103, 126],
#       'url': 'https://t.co/cniTtctmW3'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822371983203545088,
#    'id_str': '822371983203545088',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'El #BigData de los que interactúan en Internet mientras ven una serie en la TV está revolucionando el… https://t.co/cniTtctmW3',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue May 31 10:17:58 +0000 2016',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'COMbyCOM es un grupo ibérico de comunicación transmedia // COMbyCOM somos um grupo ibérico de comunicação transmedia',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'grupocombycom.com',
#         'expanded_url': 'http://grupocombycom.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/bdNq36yOXX'}]}},
#     'favourites_count': 24,
#     'follow_request_sent': False,
#     'followers_count': 60,
#     'following': False,
#     'friends_count': 40,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 737588924369932288,
#     'id_str': '737588924369932288',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 28,
#     'location': 'España/Portugal',
#     'name': 'COMbyCOM',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737588924369932288/1464690094',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/737605182901489664/a52_mHxu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/737605182901489664/a52_mHxu_normal.jpg',
#     'profile_link_color': 'FF691F',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'GrupoCOMbyCOM',
#     'statuses_count': 156,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/bdNq36yOXX',
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:15:16 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'ht.ly/czS6308aAns',
#       'expanded_url': 'http://ht.ly/czS6308aAns',
#       'indices': [68, 91],
#       'url': 'https://t.co/g6F0DeoP11'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822371906103967744,
#    'id_str': '822371906103967744',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'Big Data y tecnología o el futuro del turismo (ahora) en Fitur 2017 https://t.co/g6F0DeoP11',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Nov 06 15:33:03 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'PROMOTE THE COMPETITIVENESS & INNOVATION OF COMPANIES. 🌎 International Business 💬 Opinion & Fieldwork 🔎 Market Research 👥 PR & Marketing 💻 E-learning',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'catmi-asociacion.com',
#         'expanded_url': 'http://www.catmi-asociacion.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/qUklWxskPm'}]}},
#     'favourites_count': 137,
#     'follow_request_sent': False,
#     'followers_count': 847,
#     'following': False,
#     'friends_count': 2494,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 795287889508712448,
#     'id_str': '795287889508712448',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 7,
#     'location': 'Barcelona, España',
#     'name': 'CATMI',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/795287889508712448/1483963966',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/822076788176252928/G_Ohs4GI_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822076788176252928/G_Ohs4GI_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'catmioficial',
#     'statuses_count': 183,
#     'time_zone': 'Pacific Time (US & Canada)',
#     'translator_type': 'none',
#     'url': 'https://t.co/qUklWxskPm',
#     'utc_offset': -28800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:12:39 +0000 2017',
#    'entities': {'hashtags': [{'indices': [72, 82], 'text': 'FITUR2017'}],
#     'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#       'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#       'id': 822072218540773377,
#       'id_str': '822072218540773377',
#       'indices': [107, 130],
#       'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#        'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#        'small': {'h': 364, 'resize': 'fit', 'w': 626},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 822077403832799232,
#       'source_status_id_str': '822077403832799232',
#       'source_user_id': 18045145,
#       'source_user_id_str': '18045145',
#       'type': 'photo',
#       'url': 'https://t.co/ubdma14XEu'}],
#     'symbols': [],
#     'urls': [{'display_url': 'marketingdirecto.com/marketing-gene…',
#       'expanded_url': 'https://www.marketingdirecto.com/marketing-general/tendencias/big-data-tecnologia-futuro-turismo-ahora-fitur-2017',
#       'indices': [83, 106],
#       'url': 'https://t.co/vNyLZiumdW'}],
#     'user_mentions': [{'id': 18045145,
#       'id_str': '18045145',
#       'indices': [3, 13],
#       'name': 'MarketingDirecto.com',
#       'screen_name': 'mkdirecto'}]},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#       'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#       'id': 822072218540773377,
#       'id_str': '822072218540773377',
#       'indices': [107, 130],
#       'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#        'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#        'small': {'h': 364, 'resize': 'fit', 'w': 626},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'source_status_id': 822077403832799232,
#       'source_status_id_str': '822077403832799232',
#       'source_user_id': 18045145,
#       'source_user_id_str': '18045145',
#       'type': 'photo',
#       'url': 'https://t.co/ubdma14XEu'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822371251691786240,
#    'id_str': '822371251691786240',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Jan 19 13:45:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [57, 67], 'text': 'FITUR2017'}],
#      'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#        'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#        'id': 822072218540773377,
#        'id_str': '822072218540773377',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#        'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#         'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#         'small': {'h': 364, 'resize': 'fit', 'w': 626},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/ubdma14XEu'}],
#      'symbols': [],
#      'urls': [{'display_url': 'marketingdirecto.com/marketing-gene…',
#        'expanded_url': 'https://www.marketingdirecto.com/marketing-general/tendencias/big-data-tecnologia-futuro-turismo-ahora-fitur-2017',
#        'indices': [68, 91],
#        'url': 'https://t.co/vNyLZiumdW'}],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#        'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#        'id': 822072218540773377,
#        'id_str': '822072218540773377',
#        'indices': [92, 115],
#        'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#        'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#         'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#         'small': {'h': 364, 'resize': 'fit', 'w': 626},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/ubdma14XEu'}]},
#     'favorite_count': 8,
#     'favorited': False,
#     'geo': None,
#     'id': 822077403832799232,
#     'id_str': '822077403832799232',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 13,
#     'retweeted': False,
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'text': 'Big Data y tecnología o el futuro del turismo (ahora) en #FITUR2017 https://t.co/vNyLZiumdW https://t.co/ubdma14XEu',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Dec 11 10:38:48 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'El portal líder en información sobre marketing, publicidad, medios y nuevas tecnologías. El medio más leído por los anunciantes según @SCOPEN_es.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'marketingdirecto.com',
#          'expanded_url': 'http://www.marketingdirecto.com',
#          'indices': [0, 23],
#          'url': 'https://t.co/p9IkVHYppp'}]}},
#      'favourites_count': 5437,
#      'follow_request_sent': False,
#      'followers_count': 334544,
#      'following': False,
#      'friends_count': 111,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 18045145,
#      'id_str': '18045145',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 10929,
#      'location': 'Madrid (España)',
#      'name': 'MarketingDirecto.com',
#      'notifications': False,
#      'profile_background_color': '131516',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/574481801348968448/6WnxL4rT.jpeg',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/574481801348968448/6WnxL4rT.jpeg',
#      'profile_background_tile': True,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18045145/1483966670',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/818371094566567936/Pq5E7Q_y_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818371094566567936/Pq5E7Q_y_normal.jpg',
#      'profile_link_color': '009999',
#      'profile_sidebar_border_color': 'EEEEEE',
#      'profile_sidebar_fill_color': 'EFEFEF',
#      'profile_text_color': '333333',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'mkdirecto',
#      'statuses_count': 77817,
#      'time_zone': 'Madrid',
#      'translator_type': 'none',
#      'url': 'https://t.co/p9IkVHYppp',
#      'utc_offset': 3600,
#      'verified': True}},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'RT @mkdirecto: Big Data y tecnología o el futuro del turismo (ahora) en #FITUR2017 https://t.co/vNyLZiumdW https://t.co/ubdma14XEu',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Dec 01 11:17:49 +0000 2014',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Pegados a la actualidad del mundo del #datascience, el análisis, el #bigdata y los modelos...pero con los pies sobre el negocio.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'piperlab.es',
#         'expanded_url': 'http://www.piperlab.es',
#         'indices': [0, 22],
#         'url': 'http://t.co/EEUUTLMViG'}]}},
#     'favourites_count': 626,
#     'follow_request_sent': False,
#     'followers_count': 1108,
#     'following': False,
#     'friends_count': 1524,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 2900471446,
#     'id_str': '2900471446',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 164,
#     'location': 'Madrid, Comunidad de Madrid',
#     'name': 'PiperLab',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2900471446/1421680865',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/699475255748861957/duOBRcfH_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/699475255748861957/duOBRcfH_normal.jpg',
#     'profile_link_color': '000000',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'piperlab_es',
#     'statuses_count': 1924,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/EEUUTLMViG',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:11:53 +0000 2017',
#    'entities': {'hashtags': [{'indices': [120, 138],
#       'text': 'MuerteDestrucción'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822371055759081472,
#    'id_str': '822371055759081472',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': 'A ver, tanta transformación digital, big data y doc online, para que te pidan imprimir documento para enviarlo por fax. #MuerteDestrucción',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Nov 23 23:27:42 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Emprendedora, Conectora, Friki, Geek, #GrowthHacker, #Comunicacióncorporativa, #Marketing, RRPP, #Blogger Lifestyle, Formadora en TAC #MetodoMOA',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'moaconsulting.es',
#         'expanded_url': 'http://www.moaconsulting.es',
#         'indices': [0, 23],
#         'url': 'https://t.co/ktfgEzjOxK'}]}},
#     'favourites_count': 12442,
#     'follow_request_sent': False,
#     'followers_count': 5535,
#     'following': False,
#     'friends_count': 2947,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 17580544,
#     'id_str': '17580544',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 598,
#     'location': 'Tenerife, España',
#     'name': 'Elena del Real',
#     'notifications': False,
#     'profile_background_color': 'CC3366',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/591592887982247936/mLYD8gir.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/591592887982247936/mLYD8gir.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17580544/1455474586',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/790570273338748928/x_2cju2r_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/790570273338748928/x_2cju2r_normal.jpg',
#     'profile_link_color': 'CC3366',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F3F3F3',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'moadiario',
#     'statuses_count': 66755,
#     'time_zone': 'London',
#     'translator_type': 'none',
#     'url': 'https://t.co/ktfgEzjOxK',
#     'utc_offset': 0,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:07:39 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'bez.es/859463152/Big-…',
#       'expanded_url': 'http://www.bez.es/859463152/Big-data-y-television-personalizada-para-lidiar-con-la-burbuja-de-series.html',
#       'indices': [83, 106],
#       'url': 'https://t.co/Bb8TM9BIfF'}],
#     'user_mentions': [{'id': 213247074,
#       'id_str': '213247074',
#       'indices': [66, 82],
#       'name': 'esther ortiz',
#       'screen_name': 'estherortizvazq'},
#      {'id': 3122283251,
#       'id_str': '3122283251',
#       'indices': [111, 121],
#       'name': 'bezdiario',
#       'screen_name': 'bezdiario'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822369992251277312,
#    'id_str': '822369992251277312',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': {'attributes': {},
#     'bounding_box': {'coordinates': [[[-3.8890049, 40.3120713],
#        [-3.5180102, 40.3120713],
#        [-3.5180102, 40.6435181],
#        [-3.8890049, 40.6435181]]],
#      'type': 'Polygon'},
#     'contained_within': [],
#     'country': 'Spain',
#     'country_code': 'ES',
#     'full_name': 'Madrid, Spain',
#     'id': '206c436ce43a43a3',
#     'name': 'Madrid',
#     'place_type': 'city',
#     'url': 'https://api.twitter.com/1.1/geo/id/206c436ce43a43a3.json'},
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Contra la "burbuja" de series, `big data´ y televisión a la carta @estherortizvazq https://t.co/Bb8TM9BIfF vía @bezdiario',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Oct 08 17:33:21 +0000 2007',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Mixing digital with TV, tech, games and data. Designing industry upgrade at Tarkinia. @InnovacionAv member #tv #transmedia #eSports #robots #drones #music',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'expanded_url': None,
#         'indices': [0, 19],
#         'url': 'http://t.co/fasensi'}]}},
#     'favourites_count': 1608,
#     'follow_request_sent': False,
#     'followers_count': 2625,
#     'following': False,
#     'friends_count': 1897,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 9312802,
#     'id_str': '9312802',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 193,
#     'location': 'Madrid',
#     'name': 'Francisco Asensi',
#     'notifications': False,
#     'profile_background_color': '9AE4E8',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/2379553/Imagen006.jpg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/2379553/Imagen006.jpg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9312802/1444714051',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/814061771279519744/JnB5PZn__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/814061771279519744/JnB5PZn__normal.jpg',
#     'profile_link_color': 'A5A5C7',
#     'profile_sidebar_border_color': '87BC44',
#     'profile_sidebar_fill_color': 'E0FF92',
#     'profile_text_color': '000000',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'fasensi',
#     'statuses_count': 4390,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/fasensi',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:07:12 +0000 2017',
#    'entities': {'hashtags': [{'indices': [35, 43], 'text': 'BigData'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#       'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#       'indices': [84, 107],
#       'url': 'https://t.co/3Act0GG4C8'}],
#     'user_mentions': [{'id': 218790418,
#       'id_str': '218790418',
#       'indices': [3, 18],
#       'name': 'Centro privado I+D+i',
#       'screen_name': 'IIConocimiento'},
#      {'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [112, 122],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822369876626898950,
#    'id_str': '822369876626898950',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Jan 20 09:06:06 +0000 2017',
#     'entities': {'hashtags': [{'indices': [15, 23], 'text': 'BigData'}],
#      'symbols': [],
#      'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#        'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#        'indices': [64, 87],
#        'url': 'https://t.co/3Act0GG4C8'}],
#      'user_mentions': [{'id': 2672895854,
#        'id_str': '2672895854',
#        'indices': [92, 102],
#        'name': 'IT User (ITDM)',
#        'screen_name': 'ITUser_es'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 822369599249207298,
#     'id_str': '822369599249207298',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 13,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#     'text': '6 Impactos del #BigData y la analítica en las organizaciones ➡️ https://t.co/3Act0GG4C8 vía @ITUser_es',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Nov 23 08:30:00 +0000 2010',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'En el Instituto de Ingeniería del Conocimiento (IIC) llevamos más de 25 años transformando datos en valor. #BigData #DataScience #MachineLearning',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'iic.uam.es',
#          'expanded_url': 'http://www.iic.uam.es',
#          'indices': [0, 22],
#          'url': 'http://t.co/YGkk5VVAeI'}]}},
#      'favourites_count': 3810,
#      'follow_request_sent': False,
#      'followers_count': 2406,
#      'following': False,
#      'friends_count': 1951,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 218790418,
#      'id_str': '218790418',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 393,
#      'location': 'Madrid, España',
#      'name': 'Centro privado I+D+i',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#      'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/218790418/1425481599',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/573090213364281344/yZVdIXqL_normal.jpeg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/573090213364281344/yZVdIXqL_normal.jpeg',
#      'profile_link_color': 'D32F12',
#      'profile_sidebar_border_color': '97C714',
#      'profile_sidebar_fill_color': '242424',
#      'profile_text_color': 'F0F0F0',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'IIConocimiento',
#      'statuses_count': 5624,
#      'time_zone': 'Madrid',
#      'translator_type': 'none',
#      'url': 'http://t.co/YGkk5VVAeI',
#      'utc_offset': 3600,
#      'verified': False}},
#    'source': '<a href="http://www.jsmoral.com" rel="nofollow">My Content App for Twitter</a>',
#    'text': 'RT @IIConocimiento: 6 Impactos del #BigData y la analítica en las organizaciones ➡️ https://t.co/3Act0GG4C8 vía @ITUser_es',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jul 23 08:50:37 +0000 2014',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Revista #digital e #interactiva sobre #TI orientada a #CIO #CTO #CSO #CISO #CMO #CxO en la empresa. Podéis descargarla en https://t.co/EXwlOfgCID',
#     'entities': {'description': {'urls': [{'display_url': 'bit.ly/ITuser19tw',
#         'expanded_url': 'http://bit.ly/ITuser19tw',
#         'indices': [122, 145],
#         'url': 'https://t.co/EXwlOfgCID'}]},
#      'url': {'urls': [{'display_url': 'ituser.es',
#         'expanded_url': 'http://www.ituser.es',
#         'indices': [0, 22],
#         'url': 'http://t.co/1EMx8cYWSM'}]}},
#     'favourites_count': 28496,
#     'follow_request_sent': False,
#     'followers_count': 15635,
#     'following': False,
#     'friends_count': 12088,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 2672895854,
#     'id_str': '2672895854',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 1185,
#     'location': 'Madrid',
#     'name': 'IT User (ITDM)',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2672895854/1427133029',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/580064206579462144/Cwg4VAtA_normal.png',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/580064206579462144/Cwg4VAtA_normal.png',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'ITUser_es',
#     'statuses_count': 24772,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/1EMx8cYWSM',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:07:11 +0000 2017',
#    'entities': {'hashtags': [{'indices': [35, 43], 'text': 'BigData'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#       'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#       'indices': [84, 107],
#       'url': 'https://t.co/3Act0GG4C8'}],
#     'user_mentions': [{'id': 218790418,
#       'id_str': '218790418',
#       'indices': [3, 18],
#       'name': 'Centro privado I+D+i',
#       'screen_name': 'IIConocimiento'},
#      {'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [112, 122],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822369873758064643,
#    'id_str': '822369873758064643',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Jan 20 09:06:06 +0000 2017',
#     'entities': {'hashtags': [{'indices': [15, 23], 'text': 'BigData'}],
#      'symbols': [],
#      'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#        'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#        'indices': [64, 87],
#        'url': 'https://t.co/3Act0GG4C8'}],
#      'user_mentions': [{'id': 2672895854,
#        'id_str': '2672895854',
#        'indices': [92, 102],
#        'name': 'IT User (ITDM)',
#        'screen_name': 'ITUser_es'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 822369599249207298,
#     'id_str': '822369599249207298',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 13,
#     'retweeted': False,
#     'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
# ...
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': -36000,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 07:19:30 +0000 2017',
#    'entities': {'hashtags': [{'indices': [38, 46], 'text': 'Bigdata'},
#      {'indices': [84, 89], 'text': 'RRHH'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/go-to/8569',
#       'expanded_url': 'http://www.ituser.es/go-to/8569',
#       'indices': [90, 113],
#       'url': 'https://t.co/PkDHtI6zZa'}],
#     'user_mentions': [{'id': 974530466,
#       'id_str': '974530466',
#       'indices': [3, 14],
#       'name': 'Rafael Ruz',
#       'screen_name': 'rruzmuriel'},
#      {'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [118, 128],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 822342775660314624,
#    'id_str': '822342775660314624',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Jan 20 07:02:01 +0000 2017',
#     'entities': {'hashtags': [{'indices': [22, 30], 'text': 'Bigdata'},
#       {'indices': [68, 73], 'text': 'RRHH'}],
#      'symbols': [],
#      'urls': [{'display_url': 'ituser.es/go-to/8569',
#        'expanded_url': 'http://www.ituser.es/go-to/8569',
#        'indices': [74, 97],
#        'url': 'https://t.co/PkDHtI6zZa'}],
#      'user_mentions': [{'id': 2672895854,
#        'id_str': '2672895854',
#        'indices': [102, 112],
#        'name': 'IT User (ITDM)',
#        'screen_name': 'ITUser_es'}]},
#     'favorite_count': 6,
#     'favorited': False,
#     'geo': None,
#     'id': 822338374929354752,
#     'id_str': '822338374929354752',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 18,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'text': 'Los seis impactos del #Bigdata y la analítica en las organizaciones #RRHH https://t.co/PkDHtI6zZa vía @ITUser_es',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Nov 27 19:30:46 +0000 2012',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Unido al ámbito de los #RRHH. Alzando #competencias.Explorando nuevas oportunidades. Graduado en Ciencias del Trabajo, Relaciones Laborales y RRHH. Técnico #PRL',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'rruzmuriel.wordpress.com',
#          'expanded_url': 'https://rruzmuriel.wordpress.com/',
#          'indices': [0, 23],
#          'url': 'https://t.co/1n3RAuFlOZ'}]}},
#      'favourites_count': 77,
#      'follow_request_sent': False,
#      'followers_count': 206,
#      'following': False,
#      'friends_count': 486,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 974530466,
#      'id_str': '974530466',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': 'es',
#      'listed_count': 62,
#      'location': 'Granada, Andalucía',
#      'name': 'Rafael Ruz',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/974530466/1466350373',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/720188046503768064/Yvux6nO1_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720188046503768064/Yvux6nO1_normal.jpg',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'rruzmuriel',
#      'statuses_count': 516,
#      'time_zone': 'Brasilia',
#      'translator_type': 'none',
#      'url': 'https://t.co/1n3RAuFlOZ',
#      'utc_offset': -7200,
#      'verified': False}},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'RT @rruzmuriel: Los seis impactos del #Bigdata y la analítica en las organizaciones #RRHH https://t.co/PkDHtI6zZa vía @ITUser_es',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sun Apr 10 12:41:37 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'un madrileño... con espíritu irlandés XD #soñador #friky Amante de la cultura oriental y de la buena música  ♏♏ (;,;) \\m/',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'twitter.com/elcocinillas2',
#         'expanded_url': 'https://twitter.com/elcocinillas2',
#         'indices': [0, 23],
#         'url': 'https://t.co/2GirhsZHmv'}]}},
#     'favourites_count': 2862,
#     'follow_request_sent': False,
#     'followers_count': 118,
#     'following': False,
#     'friends_count': 312,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 280001443,
#     'id_str': '280001443',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 21,
#     'location': 'el mundo',
#     'name': 'PATRY',
#     'notifications': False,
#     'profile_background_color': 'EDECE9',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000049096453/cce33da320a749be574c9d70fdd901dd.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000049096453/cce33da320a749be574c9d70fdd901dd.jpeg',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/280001443/1410423297',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/711283054782910464/4NTgYHus_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711283054782910464/4NTgYHus_normal.jpg',
#     'profile_link_color': '088253',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'patryirlandes',
#     'statuses_count': 6856,
#     'time_zone': 'Greenland',
#     'translator_type': 'none',
#     'url': 'https://t.co/2GirhsZHmv',
#     'utc_offset': -10800,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 07:18:07 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 128241128,
#       'id_str': '128241128',
#       'indices': [0, 11],
#       'name': 'FESTIVAL CRUÏLLA',
#       'screen_name': 'cruillabcn'},
#      {'id': 14334375,
#       'id_str': '14334375',
#       'indices': [66, 79],
#       'name': 'Eurecat',
#       'screen_name': 'Eurecat_news'}]},
#    'favorite_count': 4,
#    'favorited': False,
#    'geo': None,
#    'id': 822342425368809472,
#    'id_str': '822342425368809472',
#    'in_reply_to_screen_name': 'cruillabcn',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': 128241128,
#    'in_reply_to_user_id_str': '128241128',
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 2,
#    'retweeted': False,
#    'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#    'text': '@cruillabcn segunda etapa hacía el conocimiento de su público con @Eurecat_news. Big Data al servicio de las Experiencias personalizadas!',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Dec 22 17:20:36 +0000 2009',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'cruillabarcelona.com',
#         'expanded_url': 'http://www.cruillabarcelona.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/p21Jb4uesV'}]}},
#     'favourites_count': 22,
#     'follow_request_sent': False,
#     'followers_count': 564,
#     'following': False,
#     'friends_count': 684,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 98678933,
#     'id_str': '98678933',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 12,
#     'location': '',
#     'name': 'Jordi Herreruela',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/98678933/1484486320',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/560106687936225280/K1lyzyEj_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560106687936225280/K1lyzyEj_normal.jpeg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'JordiHerreruela',
#     'statuses_count': 163,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'https://t.co/p21Jb4uesV',
#     'utc_offset': 3600,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 07:15:08 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'puromarketing.com/30/28217/big-d…',
#       'expanded_url': 'http://www.puromarketing.com/30/28217/big-data-para-medios-digitales-tienen-small-data.html',
#       'indices': [61, 84],
#       'url': 'https://t.co/lGAXQCeLEV'}],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 822341674298994688,
#    'id_str': '822341674298994688',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '"Big Data" para los medios digitales que tienen "Small Data" https://t.co/lGAXQCeLEV',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon May 30 10:35:15 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Apasionada por el crecimiento personal, Deportes, Superacion Personal. Soltero y sin ataduras. #Coaching #Motivacion #coach #yoga #RRSS #Comunicacion #PNL',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 212,
#     'follow_request_sent': False,
#     'followers_count': 300,
#     'following': False,
#     'friends_count': 807,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 737230886270337024,
#     'id_str': '737230886270337024',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 86,
#     'location': '',
#     'name': 'Cassandra Gomez',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737230886270337024/1465490659',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/737231299069480960/L87S3xsk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/737231299069480960/L87S3xsk_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'averyoswald94',
#     'statuses_count': 3642,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 07:11:56 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'puromarketing.com/30/28217/big-d…',
#       'expanded_url': 'http://www.puromarketing.com/30/28217/big-data-para-medios-digitales-tienen-small-data.html',
#       'indices': [61, 84],
#       'url': 'https://t.co/Rj3u8VMvIH'}],
#     'user_mentions': []},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 822340870854897664,
#    'id_str': '822340870854897664',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': '"Big Data" para los medios digitales que tienen "Small Data" https://t.co/Rj3u8VMvIH',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Sat Jun 11 08:59:10 +0000 2016',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'En el amor todo termina cuando uno de los amantes piensa que sería posible una ruptura. (Paul Bourget)',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 215,
#     'follow_request_sent': False,
#     'followers_count': 287,
#     'following': False,
#     'friends_count': 794,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 741555361895874560,
#     'id_str': '741555361895874560',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 91,
#     'location': '',
#     'name': 'Alaia Perez',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/741555361895874560/1465782828',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/741555804617248768/G5NZKIGv_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741555804617248768/G5NZKIGv_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'alyssas62720784',
#     'statuses_count': 3597,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False}}]}

# %%
search_results['statuses']
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:20:18 +0000 2017',
#   'entities': {'hashtags': [{'indices': [0, 8], 'text': 'BigData'},
#     {'indices': [82, 92], 'text': 'SmartCity'}],
#    'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#      'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#      'id': 822373172460867584,
#      'id_str': '822373172460867584',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#      'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#       'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#       'small': {'h': 607, 'resize': 'fit', 'w': 500},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/S2go0oLgPW'}],
#    'symbols': [],
#    'urls': [{'display_url': 'bit.ly/2j1mMWW',
#      'expanded_url': 'http://bit.ly/2j1mMWW',
#      'indices': [58, 81],
#      'url': 'https://t.co/iQJYS78ZDD'}],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#      'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#      'id': 822373172460867584,
#      'id_str': '822373172460867584',
#      'indices': [93, 116],
#      'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#      'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#       'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#       'small': {'h': 607, 'resize': 'fit', 'w': 500},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/S2go0oLgPW'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822373174771937280,
#   'id_str': '822373174771937280',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': '#BigData en las ciudades y ejemplos perfectos de utilidad https://t.co/iQJYS78ZDD #SmartCity https://t.co/S2go0oLgPW',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Nov 29 00:40:22 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '#Comunicación #Marketing #Tech #BigData #SmartCity #DirCom #Cloud #Digital',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 896,
#    'follow_request_sent': False,
#    'followers_count': 1892,
#    'following': False,
#    'friends_count': 1586,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 423842030,
#    'id_str': '423842030',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 99,
#    'location': '',
#    'name': 'Nacho Albert López',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/423842030/1455270387',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#    'profile_link_color': '0C087F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Nachoctv',
#    'statuses_count': 706,
#    'time_zone': 'Belgrade',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:19:26 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'ticbeat.com/tecnologias/al…',
#      'expanded_url': 'http://www.ticbeat.com/tecnologias/alibaba-servicios-big-data-middleware/',
#      'indices': [78, 101],
#      'url': 'https://t.co/F274EhLSAr'}],
#    'user_mentions': [{'id': 82061776,
#      'id_str': '82061776',
#      'indices': [106, 114],
#      'name': 'TICbeat',
#      'screen_name': 'ticbeat'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822372958211452928,
#   'id_str': '822372958211452928',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'El gigante chino Alibaba lanza alianza para luchar contra las falsificaciones https://t.co/F274EhLSAr vía @ticbeat',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Aug 09 21:39:20 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 22961,
#    'follow_request_sent': False,
#    'followers_count': 3769,
#    'following': False,
#    'friends_count': 3845,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 351895201,
#    'id_str': '351895201',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 49,
#    'location': 'Canary Islands (Spain)',
#    'name': 'José Pablo',
#    'notifications': False,
#    'profile_background_color': 'FFFFFF',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/450336226394906624/R7XfDFng.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/450336226394906624/R7XfDFng.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/351895201/1468796572',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/809139692272762881/7A5pGOcM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/809139692272762881/7A5pGOcM_normal.jpg',
#    'profile_link_color': '22A7BF',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'JPabloGlezRob',
#    'statuses_count': 34660,
#    'time_zone': 'London',
#    'translator_type': 'regular',
#    'url': None,
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:18:03 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'theguardian.com/politics/2017/…',
#      'expanded_url': 'https://www.theguardian.com/politics/2017/jan/19/crisis-of-statistics-big-data-democracy',
#      'indices': [72, 95],
#      'url': 'https://t.co/wL1Sdr2y0r'}],
#    'user_mentions': [{'id': 1477811,
#      'id_str': '1477811',
#      'indices': [3, 12],
#      'name': 'Antonio Delgado',
#      'screen_name': 'adelgado'},
#     {'id': 10361342,
#      'id_str': '10361342',
#      'indices': [100, 109],
#      'name': 'Kiko Llaneras',
#      'screen_name': 'kikollan'},
#     {'id': 69350769,
#      'id_str': '69350769',
#      'indices': [110, 121],
#      'name': 'Josu Mezo',
#      'screen_name': 'malaprensa'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822372606628151296,
#   'id_str': '822372606628151296',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 3,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 08:27:09 +0000 2017',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'theguardian.com/politics/2017/…',
#       'expanded_url': 'https://www.theguardian.com/politics/2017/jan/19/crisis-of-statistics-big-data-democracy',
#       'indices': [58, 81],
#       'url': 'https://t.co/wL1Sdr2y0r'}],
#     'user_mentions': [{'id': 10361342,
#       'id_str': '10361342',
#       'indices': [86, 95],
#       'name': 'Kiko Llaneras',
#       'screen_name': 'kikollan'},
#      {'id': 69350769,
#       'id_str': '69350769',
#       'indices': [96, 107],
#       'name': 'Josu Mezo',
#       'screen_name': 'malaprensa'}]},
#    'favorite_count': 8,
#    'favorited': False,
#    'geo': None,
#    'id': 822359801258790912,
#    'id_str': '822359801258790912',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 3,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': 'Cómo la estadística pierde su poder y el miedo al bigdata https://t.co/wL1Sdr2y0r  cc @kikollan @malaprensa',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Mar 19 06:57:30 +0000 2007',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Periodista. Datos y visualización. Cofundador @datadista. Innovación editorial @Weblogssl. Profesor #ddj.  Organizo @redadaes PGP https://t.co/k9ThLpdBOx',
#     'entities': {'description': {'urls': [{'display_url': 'j.mp/adelgadokey',
#         'expanded_url': 'http://j.mp/adelgadokey',
#         'indices': [130, 153],
#         'url': 'https://t.co/k9ThLpdBOx'}]},
#      'url': {'urls': [{'display_url': 'antonio-delgado.com',
#         'expanded_url': 'http://www.antonio-delgado.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/IsrzN0nNUR'}]}},
#     'favourites_count': 13321,
#     'follow_request_sent': False,
#     'followers_count': 34453,
#     'following': False,
#     'friends_count': 2309,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1477811,
#     'id_str': '1477811',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 2139,
#     'location': 'Madrid - Jerez - Valencia',
#     'name': 'Antonio Delgado',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1477811/1347995966',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1783118571/adelgado2011_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1783118571/adelgado2011_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'adelgado',
#     'statuses_count': 48189,
#     'time_zone': 'Madrid',
#     'translator_type': 'regular',
#     'url': 'https://t.co/IsrzN0nNUR',
#     'utc_offset': 3600,
#     'verified': True}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @adelgado: Cómo la estadística pierde su poder y el miedo al bigdata https://t.co/wL1Sdr2y0r  cc @kikollan @malaprensa',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu May 27 14:24:06 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Obstinada en investigar la comunicación digital (UV-UAB). Con mil proyectos en la cabeza y sin dejar de soñar. | 0x2B8F3C65',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 602,
#    'follow_request_sent': False,
#    'followers_count': 267,
#    'following': False,
#    'friends_count': 415,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 148753280,
#    'id_str': '148753280',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 18,
#    'location': 'Luna de Valencia',
#    'name': 'Lorena Cano-Orón',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/339385277/Mariposas_Dal_.JPG',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/339385277/Mariposas_Dal_.JPG',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/148753280/1479375550',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/806761564611092480/ZmmUr-Lc_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/806761564611092480/ZmmUr-Lc_normal.jpg',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': '8EC1E8',
#    'profile_sidebar_fill_color': 'CDEFF7',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Loreneando',
#    'statuses_count': 2419,
#    'time_zone': 'Greenland',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:15:34 +0000 2017',
#   'entities': {'hashtags': [{'indices': [3, 11], 'text': 'BigData'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/8…',
#      'expanded_url': 'https://twitter.com/i/web/status/822371983203545088',
#      'indices': [103, 126],
#      'url': 'https://t.co/cniTtctmW3'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822371983203545088,
#   'id_str': '822371983203545088',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'El #BigData de los que interactúan en Internet mientras ven una serie en la TV está revolucionando el… https://t.co/cniTtctmW3',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue May 31 10:17:58 +0000 2016',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'COMbyCOM es un grupo ibérico de comunicación transmedia // COMbyCOM somos um grupo ibérico de comunicação transmedia',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'grupocombycom.com',
#        'expanded_url': 'http://grupocombycom.com/',
#        'indices': [0, 23],
#        'url': 'https://t.co/bdNq36yOXX'}]}},
#    'favourites_count': 24,
#    'follow_request_sent': False,
#    'followers_count': 60,
#    'following': False,
#    'friends_count': 40,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 737588924369932288,
#    'id_str': '737588924369932288',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 28,
#    'location': 'España/Portugal',
#    'name': 'COMbyCOM',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737588924369932288/1464690094',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/737605182901489664/a52_mHxu_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/737605182901489664/a52_mHxu_normal.jpg',
#    'profile_link_color': 'FF691F',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'GrupoCOMbyCOM',
#    'statuses_count': 156,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/bdNq36yOXX',
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:15:16 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'ht.ly/czS6308aAns',
#      'expanded_url': 'http://ht.ly/czS6308aAns',
#      'indices': [68, 91],
#      'url': 'https://t.co/g6F0DeoP11'}],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822371906103967744,
#   'id_str': '822371906103967744',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'Big Data y tecnología o el futuro del turismo (ahora) en Fitur 2017 https://t.co/g6F0DeoP11',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Nov 06 15:33:03 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'PROMOTE THE COMPETITIVENESS & INNOVATION OF COMPANIES. 🌎 International Business 💬 Opinion & Fieldwork 🔎 Market Research 👥 PR & Marketing 💻 E-learning',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'catmi-asociacion.com',
#        'expanded_url': 'http://www.catmi-asociacion.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/qUklWxskPm'}]}},
#    'favourites_count': 137,
#    'follow_request_sent': False,
#    'followers_count': 847,
#    'following': False,
#    'friends_count': 2494,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 795287889508712448,
#    'id_str': '795287889508712448',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 7,
#    'location': 'Barcelona, España',
#    'name': 'CATMI',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/795287889508712448/1483963966',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/822076788176252928/G_Ohs4GI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822076788176252928/G_Ohs4GI_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'catmioficial',
#    'statuses_count': 183,
#    'time_zone': 'Pacific Time (US & Canada)',
#    'translator_type': 'none',
#    'url': 'https://t.co/qUklWxskPm',
#    'utc_offset': -28800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:12:39 +0000 2017',
#   'entities': {'hashtags': [{'indices': [72, 82], 'text': 'FITUR2017'}],
#    'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#      'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#      'id': 822072218540773377,
#      'id_str': '822072218540773377',
#      'indices': [107, 130],
#      'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#      'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#       'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#       'small': {'h': 364, 'resize': 'fit', 'w': 626},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 822077403832799232,
#      'source_status_id_str': '822077403832799232',
#      'source_user_id': 18045145,
#      'source_user_id_str': '18045145',
#      'type': 'photo',
#      'url': 'https://t.co/ubdma14XEu'}],
#    'symbols': [],
#    'urls': [{'display_url': 'marketingdirecto.com/marketing-gene…',
#      'expanded_url': 'https://www.marketingdirecto.com/marketing-general/tendencias/big-data-tecnologia-futuro-turismo-ahora-fitur-2017',
#      'indices': [83, 106],
#      'url': 'https://t.co/vNyLZiumdW'}],
#    'user_mentions': [{'id': 18045145,
#      'id_str': '18045145',
#      'indices': [3, 13],
#      'name': 'MarketingDirecto.com',
#      'screen_name': 'mkdirecto'}]},
#   'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#      'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#      'id': 822072218540773377,
#      'id_str': '822072218540773377',
#      'indices': [107, 130],
#      'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#      'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#       'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#       'small': {'h': 364, 'resize': 'fit', 'w': 626},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'source_status_id': 822077403832799232,
#      'source_status_id_str': '822077403832799232',
#      'source_user_id': 18045145,
#      'source_user_id_str': '18045145',
#      'type': 'photo',
#      'url': 'https://t.co/ubdma14XEu'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822371251691786240,
#   'id_str': '822371251691786240',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 13,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Thu Jan 19 13:45:01 +0000 2017',
#    'entities': {'hashtags': [{'indices': [57, 67], 'text': 'FITUR2017'}],
#     'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#       'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#       'id': 822072218540773377,
#       'id_str': '822072218540773377',
#       'indices': [92, 115],
#       'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#        'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#        'small': {'h': 364, 'resize': 'fit', 'w': 626},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ubdma14XEu'}],
#     'symbols': [],
#     'urls': [{'display_url': 'marketingdirecto.com/marketing-gene…',
#       'expanded_url': 'https://www.marketingdirecto.com/marketing-general/tendencias/big-data-tecnologia-futuro-turismo-ahora-fitur-2017',
#       'indices': [68, 91],
#       'url': 'https://t.co/vNyLZiumdW'}],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/ubdma14XEu',
#       'expanded_url': 'https://twitter.com/mkdirecto/status/822077403832799232/photo/1',
#       'id': 822072218540773377,
#       'id_str': '822072218540773377',
#       'indices': [92, 115],
#       'media_url': 'http://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/C2iWU8XXEAEMZbA.jpg',
#       'sizes': {'large': {'h': 364, 'resize': 'fit', 'w': 626},
#        'medium': {'h': 364, 'resize': 'fit', 'w': 626},
#        'small': {'h': 364, 'resize': 'fit', 'w': 626},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/ubdma14XEu'}]},
#    'favorite_count': 8,
#    'favorited': False,
#    'geo': None,
#    'id': 822077403832799232,
#    'id_str': '822077403832799232',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'text': 'Big Data y tecnología o el futuro del turismo (ahora) en #FITUR2017 https://t.co/vNyLZiumdW https://t.co/ubdma14XEu',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Dec 11 10:38:48 +0000 2008',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'El portal líder en información sobre marketing, publicidad, medios y nuevas tecnologías. El medio más leído por los anunciantes según @SCOPEN_es.',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'marketingdirecto.com',
#         'expanded_url': 'http://www.marketingdirecto.com',
#         'indices': [0, 23],
#         'url': 'https://t.co/p9IkVHYppp'}]}},
#     'favourites_count': 5437,
#     'follow_request_sent': False,
#     'followers_count': 334544,
#     'following': False,
#     'friends_count': 111,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 18045145,
#     'id_str': '18045145',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 10929,
#     'location': 'Madrid (España)',
#     'name': 'MarketingDirecto.com',
#     'notifications': False,
#     'profile_background_color': '131516',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/574481801348968448/6WnxL4rT.jpeg',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/574481801348968448/6WnxL4rT.jpeg',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18045145/1483966670',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/818371094566567936/Pq5E7Q_y_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/818371094566567936/Pq5E7Q_y_normal.jpg',
#     'profile_link_color': '009999',
#     'profile_sidebar_border_color': 'EEEEEE',
#     'profile_sidebar_fill_color': 'EFEFEF',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'mkdirecto',
#     'statuses_count': 77817,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'https://t.co/p9IkVHYppp',
#     'utc_offset': 3600,
#     'verified': True}},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': 'RT @mkdirecto: Big Data y tecnología o el futuro del turismo (ahora) en #FITUR2017 https://t.co/vNyLZiumdW https://t.co/ubdma14XEu',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Dec 01 11:17:49 +0000 2014',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Pegados a la actualidad del mundo del #datascience, el análisis, el #bigdata y los modelos...pero con los pies sobre el negocio.',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'piperlab.es',
#        'expanded_url': 'http://www.piperlab.es',
#        'indices': [0, 22],
#        'url': 'http://t.co/EEUUTLMViG'}]}},
#    'favourites_count': 626,
#    'follow_request_sent': False,
#    'followers_count': 1108,
#    'following': False,
#    'friends_count': 1524,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 2900471446,
#    'id_str': '2900471446',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 164,
#    'location': 'Madrid, Comunidad de Madrid',
#    'name': 'PiperLab',
#    'notifications': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2900471446/1421680865',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/699475255748861957/duOBRcfH_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/699475255748861957/duOBRcfH_normal.jpg',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'piperlab_es',
#    'statuses_count': 1924,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': 'http://t.co/EEUUTLMViG',
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:11:53 +0000 2017',
#   'entities': {'hashtags': [{'indices': [120, 138],
#      'text': 'MuerteDestrucción'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822371055759081472,
#   'id_str': '822371055759081472',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': 'A ver, tanta transformación digital, big data y doc online, para que te pidan imprimir documento para enviarlo por fax. #MuerteDestrucción',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Nov 23 23:27:42 +0000 2008',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Emprendedora, Conectora, Friki, Geek, #GrowthHacker, #Comunicacióncorporativa, #Marketing, RRPP, #Blogger Lifestyle, Formadora en TAC #MetodoMOA',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'moaconsulting.es',
#        'expanded_url': 'http://www.moaconsulting.es',
#        'indices': [0, 23],
#        'url': 'https://t.co/ktfgEzjOxK'}]}},
#    'favourites_count': 12442,
#    'follow_request_sent': False,
#    'followers_count': 5535,
#    'following': False,
#    'friends_count': 2947,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 17580544,
#    'id_str': '17580544',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 598,
#    'location': 'Tenerife, España',
#    'name': 'Elena del Real',
#    'notifications': False,
#    'profile_background_color': 'CC3366',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/591592887982247936/mLYD8gir.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/591592887982247936/mLYD8gir.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/17580544/1455474586',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/790570273338748928/x_2cju2r_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/790570273338748928/x_2cju2r_normal.jpg',
#    'profile_link_color': 'CC3366',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F3F3F3',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'moadiario',
#    'statuses_count': 66755,
#    'time_zone': 'London',
#    'translator_type': 'none',
#    'url': 'https://t.co/ktfgEzjOxK',
#    'utc_offset': 0,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:07:39 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'bez.es/859463152/Big-…',
#      'expanded_url': 'http://www.bez.es/859463152/Big-data-y-television-personalizada-para-lidiar-con-la-burbuja-de-series.html',
#      'indices': [83, 106],
#      'url': 'https://t.co/Bb8TM9BIfF'}],
#    'user_mentions': [{'id': 213247074,
#      'id_str': '213247074',
#      'indices': [66, 82],
#      'name': 'esther ortiz',
#      'screen_name': 'estherortizvazq'},
#     {'id': 3122283251,
#      'id_str': '3122283251',
#      'indices': [111, 121],
#      'name': 'bezdiario',
#      'screen_name': 'bezdiario'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822369992251277312,
#   'id_str': '822369992251277312',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-3.8890049, 40.3120713],
#       [-3.5180102, 40.3120713],
#       [-3.5180102, 40.6435181],
#       [-3.8890049, 40.6435181]]],
#     'type': 'Polygon'},
#    'contained_within': [],
#    'country': 'Spain',
#    'country_code': 'ES',
#    'full_name': 'Madrid, Spain',
#    'id': '206c436ce43a43a3',
#    'name': 'Madrid',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/206c436ce43a43a3.json'},
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Contra la "burbuja" de series, `big data´ y televisión a la carta @estherortizvazq https://t.co/Bb8TM9BIfF vía @bezdiario',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon Oct 08 17:33:21 +0000 2007',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Mixing digital with TV, tech, games and data. Designing industry upgrade at Tarkinia. @InnovacionAv member #tv #transmedia #eSports #robots #drones #music',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'expanded_url': None,
#        'indices': [0, 19],
#        'url': 'http://t.co/fasensi'}]}},
#    'favourites_count': 1608,
#    'follow_request_sent': False,
#    'followers_count': 2625,
#    'following': False,
#    'friends_count': 1897,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 9312802,
#    'id_str': '9312802',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 193,
#    'location': 'Madrid',
#    'name': 'Francisco Asensi',
#    'notifications': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/2379553/Imagen006.jpg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/2379553/Imagen006.jpg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/9312802/1444714051',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/814061771279519744/JnB5PZn__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/814061771279519744/JnB5PZn__normal.jpg',
#    'profile_link_color': 'A5A5C7',
#    'profile_sidebar_border_color': '87BC44',
#    'profile_sidebar_fill_color': 'E0FF92',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'fasensi',
#    'statuses_count': 4390,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': 'http://t.co/fasensi',
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:07:12 +0000 2017',
#   'entities': {'hashtags': [{'indices': [35, 43], 'text': 'BigData'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#      'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#      'indices': [84, 107],
#      'url': 'https://t.co/3Act0GG4C8'}],
#    'user_mentions': [{'id': 218790418,
#      'id_str': '218790418',
#      'indices': [3, 18],
#      'name': 'Centro privado I+D+i',
#      'screen_name': 'IIConocimiento'},
#     {'id': 2672895854,
#      'id_str': '2672895854',
#      'indices': [112, 122],
#      'name': 'IT User (ITDM)',
#      'screen_name': 'ITUser_es'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822369876626898950,
#   'id_str': '822369876626898950',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 13,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:06:06 +0000 2017',
#    'entities': {'hashtags': [{'indices': [15, 23], 'text': 'BigData'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#       'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#       'indices': [64, 87],
#       'url': 'https://t.co/3Act0GG4C8'}],
#     'user_mentions': [{'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [92, 102],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 822369599249207298,
#    'id_str': '822369599249207298',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': '6 Impactos del #BigData y la analítica en las organizaciones ➡️ https://t.co/3Act0GG4C8 vía @ITUser_es',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 23 08:30:00 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'En el Instituto de Ingeniería del Conocimiento (IIC) llevamos más de 25 años transformando datos en valor. #BigData #DataScience #MachineLearning',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'iic.uam.es',
#         'expanded_url': 'http://www.iic.uam.es',
#         'indices': [0, 22],
#         'url': 'http://t.co/YGkk5VVAeI'}]}},
#     'favourites_count': 3810,
#     'follow_request_sent': False,
#     'followers_count': 2406,
#     'following': False,
#     'friends_count': 1951,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 218790418,
#     'id_str': '218790418',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 393,
#     'location': 'Madrid, España',
#     'name': 'Centro privado I+D+i',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/218790418/1425481599',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/573090213364281344/yZVdIXqL_normal.jpeg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/573090213364281344/yZVdIXqL_normal.jpeg',
#     'profile_link_color': 'D32F12',
#     'profile_sidebar_border_color': '97C714',
#     'profile_sidebar_fill_color': '242424',
#     'profile_text_color': 'F0F0F0',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'IIConocimiento',
#     'statuses_count': 5624,
#     'time_zone': 'Madrid',
#     'translator_type': 'none',
#     'url': 'http://t.co/YGkk5VVAeI',
#     'utc_offset': 3600,
#     'verified': False}},
#   'source': '<a href="http://www.jsmoral.com" rel="nofollow">My Content App for Twitter</a>',
#   'text': 'RT @IIConocimiento: 6 Impactos del #BigData y la analítica en las organizaciones ➡️ https://t.co/3Act0GG4C8 vía @ITUser_es',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Jul 23 08:50:37 +0000 2014',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Revista #digital e #interactiva sobre #TI orientada a #CIO #CTO #CSO #CISO #CMO #CxO en la empresa. Podéis descargarla en https://t.co/EXwlOfgCID',
#    'entities': {'description': {'urls': [{'display_url': 'bit.ly/ITuser19tw',
#        'expanded_url': 'http://bit.ly/ITuser19tw',
#        'indices': [122, 145],
#        'url': 'https://t.co/EXwlOfgCID'}]},
#     'url': {'urls': [{'display_url': 'ituser.es',
#        'expanded_url': 'http://www.ituser.es',
#        'indices': [0, 22],
#        'url': 'http://t.co/1EMx8cYWSM'}]}},
#    'favourites_count': 28496,
#    'follow_request_sent': False,
#    'followers_count': 15635,
#    'following': False,
#    'friends_count': 12088,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 2672895854,
#    'id_str': '2672895854',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 1185,
#    'location': 'Madrid',
#    'name': 'IT User (ITDM)',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2672895854/1427133029',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/580064206579462144/Cwg4VAtA_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/580064206579462144/Cwg4VAtA_normal.png',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'ITUser_es',
#    'statuses_count': 24772,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': 'http://t.co/1EMx8cYWSM',
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 09:07:11 +0000 2017',
#   'entities': {'hashtags': [{'indices': [35, 43], 'text': 'BigData'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#      'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#      'indices': [84, 107],
#      'url': 'https://t.co/3Act0GG4C8'}],
#    'user_mentions': [{'id': 218790418,
#      'id_str': '218790418',
#      'indices': [3, 18],
#      'name': 'Centro privado I+D+i',
#      'screen_name': 'IIConocimiento'},
#     {'id': 2672895854,
#      'id_str': '2672895854',
#      'indices': [112, 122],
#      'name': 'IT User (ITDM)',
#      'screen_name': 'ITUser_es'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822369873758064643,
#   'id_str': '822369873758064643',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 13,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 09:06:06 +0000 2017',
#    'entities': {'hashtags': [{'indices': [15, 23], 'text': 'BigData'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/it-user/2017/0…',
#       'expanded_url': 'http://www.ituser.es/it-user/2017/01/los-seis-impactos-del-big-data-y-la-analitica-en-las-organizaciones',
#       'indices': [64, 87],
#       'url': 'https://t.co/3Act0GG4C8'}],
#     'user_mentions': [{'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [92, 102],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 1,
#    'favorited': False,
#    'geo': None,
#    'id': 822369599249207298,
#    'id_str': '822369599249207298',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 13,
#    'retweeted': False,
#    'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>',
#    'text': '6 Impactos del #BigData y la analítica en las organizaciones ➡️ https://t.co/3Act0GG4C8 vía @ITUser_es',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 23 08:30:00 +0000 2010',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'En el Instituto de Ingeniería del Conocimiento (IIC) llevamos más de 25 años transformando datos en valor. #BigData #DataScience #MachineLearning',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'iic.uam.es',
#         'expanded_url': 'http://www.iic.uam.es',
#         'indices': [0, 22],
#         'url': 'http://t.co/YGkk5VVAeI'}]}},
#     'favourites_count': 3810,
#     'follow_request_sent': False,
#     'followers_count': 2406,
#     'following': False,
#     'friends_count': 1951,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 218790418,
#     'id_str': '218790418',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 393,
#     'location': 'Madrid, España',
#     'name': 'Centro privado I+D+i',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#     'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/573132607841435648/tQkJb7j6.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/218790418/1425481599',
# ...
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JMarcosCatalan',
#    'statuses_count': 6640,
#    'time_zone': 'Hawaii',
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': -36000,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 07:19:30 +0000 2017',
#   'entities': {'hashtags': [{'indices': [38, 46], 'text': 'Bigdata'},
#     {'indices': [84, 89], 'text': 'RRHH'}],
#    'symbols': [],
#    'urls': [{'display_url': 'ituser.es/go-to/8569',
#      'expanded_url': 'http://www.ituser.es/go-to/8569',
#      'indices': [90, 113],
#      'url': 'https://t.co/PkDHtI6zZa'}],
#    'user_mentions': [{'id': 974530466,
#      'id_str': '974530466',
#      'indices': [3, 14],
#      'name': 'Rafael Ruz',
#      'screen_name': 'rruzmuriel'},
#     {'id': 2672895854,
#      'id_str': '2672895854',
#      'indices': [118, 128],
#      'name': 'IT User (ITDM)',
#      'screen_name': 'ITUser_es'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 822342775660314624,
#   'id_str': '822342775660314624',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 18,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Jan 20 07:02:01 +0000 2017',
#    'entities': {'hashtags': [{'indices': [22, 30], 'text': 'Bigdata'},
#      {'indices': [68, 73], 'text': 'RRHH'}],
#     'symbols': [],
#     'urls': [{'display_url': 'ituser.es/go-to/8569',
#       'expanded_url': 'http://www.ituser.es/go-to/8569',
#       'indices': [74, 97],
#       'url': 'https://t.co/PkDHtI6zZa'}],
#     'user_mentions': [{'id': 2672895854,
#       'id_str': '2672895854',
#       'indices': [102, 112],
#       'name': 'IT User (ITDM)',
#       'screen_name': 'ITUser_es'}]},
#    'favorite_count': 6,
#    'favorited': False,
#    'geo': None,
#    'id': 822338374929354752,
#    'id_str': '822338374929354752',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 18,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'text': 'Los seis impactos del #Bigdata y la analítica en las organizaciones #RRHH https://t.co/PkDHtI6zZa vía @ITUser_es',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 27 19:30:46 +0000 2012',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Unido al ámbito de los #RRHH. Alzando #competencias.Explorando nuevas oportunidades. Graduado en Ciencias del Trabajo, Relaciones Laborales y RRHH. Técnico #PRL',
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'rruzmuriel.wordpress.com',
#         'expanded_url': 'https://rruzmuriel.wordpress.com/',
#         'indices': [0, 23],
#         'url': 'https://t.co/1n3RAuFlOZ'}]}},
#     'favourites_count': 77,
#     'follow_request_sent': False,
#     'followers_count': 206,
#     'following': False,
#     'friends_count': 486,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 974530466,
#     'id_str': '974530466',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': 'es',
#     'listed_count': 62,
#     'location': 'Granada, Andalucía',
#     'name': 'Rafael Ruz',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/974530466/1466350373',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/720188046503768064/Yvux6nO1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/720188046503768064/Yvux6nO1_normal.jpg',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'rruzmuriel',
#     'statuses_count': 516,
#     'time_zone': 'Brasilia',
#     'translator_type': 'none',
#     'url': 'https://t.co/1n3RAuFlOZ',
#     'utc_offset': -7200,
#     'verified': False}},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'RT @rruzmuriel: Los seis impactos del #Bigdata y la analítica en las organizaciones #RRHH https://t.co/PkDHtI6zZa vía @ITUser_es',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Apr 10 12:41:37 +0000 2011',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'un madrileño... con espíritu irlandés XD #soñador #friky Amante de la cultura oriental y de la buena música  ♏♏ (;,;) \\m/',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'twitter.com/elcocinillas2',
#        'expanded_url': 'https://twitter.com/elcocinillas2',
#        'indices': [0, 23],
#        'url': 'https://t.co/2GirhsZHmv'}]}},
#    'favourites_count': 2862,
#    'follow_request_sent': False,
#    'followers_count': 118,
#    'following': False,
#    'friends_count': 312,
#    'geo_enabled': True,
#    'has_extended_profile': True,
#    'id': 280001443,
#    'id_str': '280001443',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 21,
#    'location': 'el mundo',
#    'name': 'PATRY',
#    'notifications': False,
#    'profile_background_color': 'EDECE9',
#    'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/378800000049096453/cce33da320a749be574c9d70fdd901dd.jpeg',
#    'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/378800000049096453/cce33da320a749be574c9d70fdd901dd.jpeg',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/280001443/1410423297',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/711283054782910464/4NTgYHus_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/711283054782910464/4NTgYHus_normal.jpg',
#    'profile_link_color': '088253',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'patryirlandes',
#    'statuses_count': 6856,
#    'time_zone': 'Greenland',
#    'translator_type': 'none',
#    'url': 'https://t.co/2GirhsZHmv',
#    'utc_offset': -10800,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 07:18:07 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 128241128,
#      'id_str': '128241128',
#      'indices': [0, 11],
#      'name': 'FESTIVAL CRUÏLLA',
#      'screen_name': 'cruillabcn'},
#     {'id': 14334375,
#      'id_str': '14334375',
#      'indices': [66, 79],
#      'name': 'Eurecat',
#      'screen_name': 'Eurecat_news'}]},
#   'favorite_count': 4,
#   'favorited': False,
#   'geo': None,
#   'id': 822342425368809472,
#   'id_str': '822342425368809472',
#   'in_reply_to_screen_name': 'cruillabcn',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': 128241128,
#   'in_reply_to_user_id_str': '128241128',
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 2,
#   'retweeted': False,
#   'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#   'text': '@cruillabcn segunda etapa hacía el conocimiento de su público con @Eurecat_news. Big Data al servicio de las Experiencias personalizadas!',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Dec 22 17:20:36 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'cruillabarcelona.com',
#        'expanded_url': 'http://www.cruillabarcelona.com',
#        'indices': [0, 23],
#        'url': 'https://t.co/p21Jb4uesV'}]}},
#    'favourites_count': 22,
#    'follow_request_sent': False,
#    'followers_count': 564,
#    'following': False,
#    'friends_count': 684,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 98678933,
#    'id_str': '98678933',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 12,
#    'location': '',
#    'name': 'Jordi Herreruela',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/98678933/1484486320',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/560106687936225280/K1lyzyEj_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/560106687936225280/K1lyzyEj_normal.jpeg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'JordiHerreruela',
#    'statuses_count': 163,
#    'time_zone': 'Madrid',
#    'translator_type': 'none',
#    'url': 'https://t.co/p21Jb4uesV',
#    'utc_offset': 3600,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 07:15:08 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'puromarketing.com/30/28217/big-d…',
#      'expanded_url': 'http://www.puromarketing.com/30/28217/big-data-para-medios-digitales-tienen-small-data.html',
#      'indices': [61, 84],
#      'url': 'https://t.co/lGAXQCeLEV'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 822341674298994688,
#   'id_str': '822341674298994688',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '"Big Data" para los medios digitales que tienen "Small Data" https://t.co/lGAXQCeLEV',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Mon May 30 10:35:15 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Apasionada por el crecimiento personal, Deportes, Superacion Personal. Soltero y sin ataduras. #Coaching #Motivacion #coach #yoga #RRSS #Comunicacion #PNL',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 212,
#    'follow_request_sent': False,
#    'followers_count': 300,
#    'following': False,
#    'friends_count': 807,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 737230886270337024,
#    'id_str': '737230886270337024',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 86,
#    'location': '',
#    'name': 'Cassandra Gomez',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/737230886270337024/1465490659',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/737231299069480960/L87S3xsk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/737231299069480960/L87S3xsk_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'averyoswald94',
#    'statuses_count': 3642,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jan 20 07:11:56 +0000 2017',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'puromarketing.com/30/28217/big-d…',
#      'expanded_url': 'http://www.puromarketing.com/30/28217/big-data-para-medios-digitales-tienen-small-data.html',
#      'indices': [61, 84],
#      'url': 'https://t.co/Rj3u8VMvIH'}],
#    'user_mentions': []},
#   'favorite_count': 1,
#   'favorited': False,
#   'geo': None,
#   'id': 822340870854897664,
#   'id_str': '822340870854897664',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'es',
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'text': '"Big Data" para los medios digitales que tienen "Small Data" https://t.co/Rj3u8VMvIH',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sat Jun 11 08:59:10 +0000 2016',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'En el amor todo termina cuando uno de los amantes piensa que sería posible una ruptura. (Paul Bourget)',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 215,
#    'follow_request_sent': False,
#    'followers_count': 287,
#    'following': False,
#    'friends_count': 794,
#    'geo_enabled': False,
#    'has_extended_profile': False,
#    'id': 741555361895874560,
#    'id_str': '741555361895874560',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'es',
#    'listed_count': 91,
#    'location': '',
#    'name': 'Alaia Perez',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/741555361895874560/1465782828',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/741555804617248768/G5NZKIGv_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741555804617248768/G5NZKIGv_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'alyssas62720784',
#    'statuses_count': 3597,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}}]

# %%
search_results['statuses'][0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jan 20 09:20:18 +0000 2017',
#  'entities': {'hashtags': [{'indices': [0, 8], 'text': 'BigData'},
#    {'indices': [82, 92], 'text': 'SmartCity'}],
#   'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#     'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#     'id': 822373172460867584,
#     'id_str': '822373172460867584',
#     'indices': [93, 116],
#     'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#     'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#      'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#      'small': {'h': 607, 'resize': 'fit', 'w': 500},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'type': 'photo',
#     'url': 'https://t.co/S2go0oLgPW'}],
#   'symbols': [],
#   'urls': [{'display_url': 'bit.ly/2j1mMWW',
#     'expanded_url': 'http://bit.ly/2j1mMWW',
#     'indices': [58, 81],
#     'url': 'https://t.co/iQJYS78ZDD'}],
#   'user_mentions': []},
#  'extended_entities': {'media': [{'display_url': 'pic.twitter.com/S2go0oLgPW',
#     'expanded_url': 'https://twitter.com/Nachoctv/status/822373174771937280/photo/1',
#     'id': 822373172460867584,
#     'id_str': '822373172460867584',
#     'indices': [93, 116],
#     'media_url': 'http://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/C2moCxFXUAA_Dih.jpg',
#     'sizes': {'large': {'h': 607, 'resize': 'fit', 'w': 500},
#      'medium': {'h': 607, 'resize': 'fit', 'w': 500},
#      'small': {'h': 607, 'resize': 'fit', 'w': 500},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'type': 'photo',
#     'url': 'https://t.co/S2go0oLgPW'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 822373174771937280,
#  'id_str': '822373174771937280',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'es',
#  'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="http://www.hootsuite.com" rel="nofollow">Hootsuite</a>',
#  'text': '#BigData en las ciudades y ejemplos perfectos de utilidad https://t.co/iQJYS78ZDD #SmartCity https://t.co/S2go0oLgPW',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Nov 29 00:40:22 +0000 2011',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '#Comunicación #Marketing #Tech #BigData #SmartCity #DirCom #Cloud #Digital',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 896,
#   'follow_request_sent': False,
#   'followers_count': 1892,
#   'following': False,
#   'friends_count': 1586,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 423842030,
#   'id_str': '423842030',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'es',
#   'listed_count': 99,
#   'location': '',
#   'name': 'Nacho Albert López',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/423842030/1455270387',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#   'profile_link_color': '0C087F',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'Nachoctv',
#   'statuses_count': 706,
#   'time_zone': 'Belgrade',
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': 3600,
#   'verified': False}}

# %%
search_results['statuses'][0]['user']
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Tue Nov 29 00:40:22 +0000 2011',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': '#Comunicación #Marketing #Tech #BigData #SmartCity #DirCom #Cloud #Digital',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 896,
#  'follow_request_sent': False,
#  'followers_count': 1892,
#  'following': False,
#  'friends_count': 1586,
#  'geo_enabled': True,
#  'has_extended_profile': False,
#  'id': 423842030,
#  'id_str': '423842030',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': 'es',
#  'listed_count': 99,
#  'location': '',
#  'name': 'Nacho Albert López',
#  'notifications': False,
#  'profile_background_color': 'C0DEED',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/423842030/1455270387',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/588714145979195393/cDviPDP3_normal.jpg',
#  'profile_link_color': '0C087F',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'Nachoctv',
#  'statuses_count': 706,
#  'time_zone': 'Belgrade',
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': 3600,
#  'verified': False}

# %% [markdown]
# Vamos a crear nuestros modelos. Primero haremos uno para los tweets, donde podremos utilizar las propiedades que querramos, pero por ejemplo, podriamos usar los siguientes:
# * `created_at`
# * `text`
# * `retweet_count`
# * `favorite_count`
# * `hashtags`
# * `urls`
# * `mentions`
# * `user_id`
#
# Para los usuarios podríamos usar algo así:
# * `created_at`
# * `screen_name`
# * `name`
# * `description`
# * `favourites_count`
# * `followers_count`
# * `friends_count`
# * `profile_image_url`
#
# Algunos de ellos no existen como tal en los resultados de la API, pero para ello podremos programar funciones que nos transformen los resultados en datos válidos para el modelo.

# %%
class Tweet(Document):
    created_at = DateTimeField(required=True)
    text = StringField()
    retweet_count = IntField(default=0)
    favorite_count = IntField(default=0)
    hashtags =ListField(StringField(max_length=100))
    urls = ListField(StringField())
    mentions = ListField(StringField())
    user_id = ObjectIdField(required=True)


class User(Document):
    created_at = DateTimeField(required=True)
    screen_name = StringField(max_length=256, required=True)
    name = StringField(max_length=256, required=True)
    description = StringField(required=True)
    favourites_count = IntField(default=0)
    followers_count = IntField(default=0)
    friends_count = IntField(default=0)
    profile_image_url = StringField()

# %%
# Function for transform the datetime from Twitter to Python's format
def twitter_date_to_datetime(twitter_date):
    return datetime.datetime.strptime(twitter_date, '%a %b %d %H:%M:%S +0000 %Y')

## Constructors for the documents
# User getter and constructor
def get_or_create_user(api_user):
    user = User.objects(screen_name=api_user['screen_name']).first()
    if not user:
        user = User()
        
        user['created_at'] = twitter_date_to_datetime(api_user['created_at'])
        user['screen_name'] = api_user['screen_name']
        ###############################################
        # Here we need a block for link more properties
        ###############################################
        user['name'] = api_user['name']
        user['description'] = api_user['description']
        user['favourites_count'] = api_user['favourites_count']
        user['followers_count']= api_user['followers_count']
        user['friends_count']= api_user['friends_count']
        user['profile_image_url']= api_user['profile_image_url']
        ##################################
        # And now we must persist the user
        ##################################
        user.save()
    return user

# Tweet constructor
def create_tweet(api_tweet, user):
    tweet = Tweet()
    
    tweet['created_at'] = twitter_date_to_datetime(api_tweet['created_at'])
    tweet['text'] = api_tweet['text']
    ###############################################
    # Here we need a block for link more properties
    ###############################################

    hashtags = [hashtag['text'] for hashtag in api_tweet['entities']['hashtags']]
    urls = [url['expanded_url'] for url in api_tweet['entities']['urls']]
    mentions = [mention['screen_name'] for mention in api_tweet['entities']['user_mentions']]
    
    tweet['hashtags'] = hashtags
    tweet['urls']=urls
    tweet['mentions']=mentions
    ###############################################
    # Here we need a block for link more properties
    ###############################################
    tweet['retweet_count'] = api_tweet['retweet_count']
    tweet['favorite_count'] = api_tweet['favorite_count']
    tweet['user_id'] = user.id
    
    ###################################
    # And now we must persist the tweet
    ###################################
    tweet.save()
    return tweet

# %% [markdown]
# Por último, vamos a rellenar nuestra base de datos con los resultados obtenidos y comprobar en RoboMongo los resultados.

# %%
for result in search_results['statuses']:
    api_user = result['user']
    user = get_or_create_user(api_user)
    tweet = create_tweet(result, user)
